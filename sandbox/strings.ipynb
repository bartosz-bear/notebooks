# %%
import pandas as pd
import numpy as np

boston = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/boston.csv")

# %%
boston.head(
)
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran
# 0        1       1       NaN
# 1        2       2       NaN
# 2        3       3       NaN
# 3        4       4       NaN
# 4        5       5      2015

# %%
s = 'Welcome to the text manipulation section'

# %%
len(s)
# Out:
# 40

# %%
s.center()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> s.center()
#
# TypeError: center expected at least 1 argument, got 0

# %%
s.center(50, '*')
# Out:
# '*****Welcome to the text manipulation section*****'

# %%
s.startswith('W')
# Out:
# True

# %%
s.endswith('w')
# Out:
# False

# %%
'text' in s
# Out:
# True

# %%
'texted' in s
# Out:
# False

# %%
s.includes('text')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> s.includes('text')
#
# AttributeError: 'str' object has no attribute 'includes'

# %%
names = ['Ainah', 'Albion', 'Andrew', 'Brian']

# %%
[name.startswith('A') for name in names]
# Out:
# [True, True, True, False]

# %%
boston.Name.str.lower()
# Out:
# 0         kirui, geoffrey
# 1           rupp, galen
# 2          osako, suguru
# 3         biwott, shadrack
# 4           chebet, wilson
#               ...
# 995           larosa, mark
# 996    williamson, jerry a
# 997        mccue, daniel t
# 998           larosa, john
# 999         sanchez, sam r
# Name: Name, Length: 1000, dtype: object

# %%
s
# Out:
# 'Welcome to the text manipulation section'

# %%
s.find('W')
# Out:
# 0

# %%
s[0]
# Out:
# 'W'

# %%
s[17]
# Out:
# 'x'

# %%
p = 'pandas numpy numpy pandas'

# %%
p.find('pandas')
# Out:
# 0

# %%
p.find('numpy')
# Out:
# 7

# %%
my_string  = 'My first string'
my_string.find('string')
# Out:
# 9

# %%
from pprint import pprint

pprint(dir(my_string))
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
p.count()
# Out:
# 2

# %%
h = 'ho ho'

# %%
h.isspace()
# Out:
# False

# %%
left_spaced = '     this is a a pandas course'

# %%
print(left_spaced)
# Out:
#      this is a a pandas course

# %%
left_spaced.lstrip()
# Out:
# 'this is a a pandas course'

# %%
a_left_spaced = 'aaaaaathis is also a course'

# %%
a_left_spaced.lstrip('a')
# Out:
# 'this is also a course'

# %%
right_string_b = 'this is a pandas coursebbbbbbb'

# %%
right_string_b.rstrip('b')
# Out:
# 'this is a pandas course'

# %%
that_string = '   hello\n\n\n'

# %%
print(that_string.strip())
# Out:
# hello

# %%
boston.Name.iloc[0]
# Out:
# ' Kirui, Geoffrey '

# %%
boston.Name.iloc[0:2].str.strip()
# Out:
# 0    Kirui, Geoffrey
# 1        Rupp, Galen
# Name: Name, dtype: object

# %%
s
# Out:
# 'Welcome to the text manipulation section'

# %%
s = '  the name is: BOND \t JAMES BOND \n\n'
s.split()
# Out:
# ['the', 'name', 'is:', 'BOND', 'JAMES', 'BOND']

# %%
s.split(' ')
# Out:
# ['', '', 'the', 'name', 'is:', 'BOND', '\t', 'JAMES', 'BOND', '\n\n']

# %%
boston['First Name'] = boston.Name.str.split(', ').str.get(0)

# %%
boston['BothNames'] = boston.Name.str.split(', ')

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran First Name            BothNames
# 0        1       1       NaN      Kirui  [ Kirui, Geoffrey ]
# 1        2       2       NaN       Rupp     [Rupp, Galen   ]
# 2        3       3       NaN      Osako    [Osako, Suguru  ]
# 3        4       4       NaN     Biwott   [Biwott, Shadrack]
# 4        5       5      2015     Chebet     [Chebet, Wilson]

# %%
boston['BothNames'].dtype
# Out:
# dtype('O')

# %%
boston['BothNames'].str.get(1)
# Out:
# 0      Geoffrey
# 1       Galen
# 2       Suguru
# 3       Shadrack
# 4         Wilson
#          ...
# 995         Mark
# 996      Jerry A
# 997     Daniel T
# 998         John
# 999        Sam R
# Name: BothNames, Length: 1000, dtype: object

# %%
boston['BothNames'].astype(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb Cell 46 line 1
# ----> <a href='vscode-notebook-cell:/Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> boston['BothNames'].astype(list)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
# ...

# %%
boston['concat'] = boston['M/F'].str.cat(boston.Age.astype(str), sep='_')

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran First Name            BothNames concat
# 0        1       1       NaN      Kirui  [ Kirui, Geoffrey ]   M_24
# 1        2       2       NaN       Rupp     [Rupp, Galen   ]   M_30
# 2        3       3       NaN      Osako    [Osako, Suguru  ]   M_25
# 3        4       4       NaN     Biwott   [Biwott, Shadrack]   M_32
# 4        5       5      2015     Chebet     [Chebet, Wilson]   M_31

# %%
boston.Name.str.split( )
# Out:
#               0          1
# 0         Kirui  Geoffrey
# 1          Rupp   Galen
# 2         Osako   Suguru
# 3        Biwott   Shadrack
# 4        Chebet     Wilson
# ..          ...        ...
# 995      Larosa       Mark
# 996  Williamson    Jerry A
# 997       Mccue   Daniel T
# 998      Larosa       John
# 999     Sanchez      Sam R
#
# [1000 rows x 2 columns]

# %%
boston['LastName'] = boston.Name.str.split(', ').str.get(1)

# %%
len(boston['LastName'][boston['LastName'] == 'James'])
# Out:
# 5

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender Years Ran First Name            BothNames concat   LastName
# 0        1       1       NaN      Kirui  [ Kirui, Geoffrey ]   M_24  Geoffrey
# 1        2       2       NaN       Rupp     [Rupp, Galen   ]   M_30   Galen
# 2        3       3       NaN      Osako    [Osako, Suguru  ]   M_25   Suguru
# 3        4       4       NaN     Biwott   [Biwott, Shadrack]   M_32   Shadrack
# 4        5       5      2015     Chebet     [Chebet, Wilson]   M_31     Wilson

# %%
city_parts = boston.City.str.split('-', expand=True)

# %%
city_parts.head()
# Out:
#                0     1     2     3
# 0       Keringet  None  None  None
# 1       Portland  None  None  None
# 2        Machida  City  None  None
# 3  Mammoth Lakes  None  None  None
# 4       Marakwet  None  None  None

# %%
counted = city_parts.count(axis=1)

# %%
len(counted[counted > 1])
# Out:
# 13

# %%
counted[counted > 1].index
# Out:
# Int64Index([2, 35, 188, 201, 371, 420, 585, 615, 724, 727, 794, 820, 830], dtype='int64')

# %%
boston.iloc[counted[counted > 1].index].City
# Out:
# 2                    Machida-City
# 35                 Sao Paulo - Sp
# 188                  Baie-St-Paul
# 201            Houghton-Le-Spring
# 371          Boulogne-Billancourt
# 420                    Mont-Royal
# 585                Gif-Sur-Yvette
# 615        Fossambault-Sur-Le-Lac
# 724         Wiesbaden-Breckenheim
# 727                    Saint-Tite
# 794                   Marica - Rj
# 820    Sainte-Catherine-De-Hatley
# 830                    Pont-Rouge
# Name: City, dtype: object

# %%
boston.Country.str.slice(start=0, stop=2, step=1)
# Out:
# 0      KE
# 1      US
# 2      JP
# 3      US
# 4      KE
#        ..
# 995    US
# 996    US
# 997    US
# 998    US
# 999    US
# Name: Country, Length: 1000, dtype: object

# %%
boston.Country.str.match('ITA')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Country, Length: 1000, dtype: bool

# %%
boston.loc[boston.Country.str.match('ITA')]
# Out:
#                           Name  Age M/F                      City State  \
# 56          Boudalia, Said Sr.   48   M                   Belluno   NaN
# 156         Achmuller, Hermann   46   M                    Brixen   NaN
# 792  Consolandi, Paolo Giorgio   39   M  Pessano Con Bornago (mi)   NaN
# 922       Zompanti, Alessandro   48   M                 Fiuggi Fr   NaN
#
#     Country Official Time  Overall  Gender  Years Ran  First Name  \
# 56      ITA       2:30:11       57      51  2015:2016    Boudalia
# 156     ITA       2:38:40      157     139        NaN   Achmuller
# 792     ITA       2:53:29      793     747        NaN  Consolandi
# 922     ITA       2:55:12      923     872        NaN    Zompanti
#
#                        BothNames concat       LastName
# 56          [Boudalia, Said Sr.]   M_48       Said Sr.
# 156         [Achmuller, Hermann]   M_46        Hermann
# 792  [Consolandi, Paolo Giorgio]   M_39  Paolo Giorgio
# ...

# %%
boston.loc[boston.Country.str.match('POL')]
# Out:
#                          Name  Age M/F       City State Country Official Time  \
# 213  Wojciechowski, Sebastian   33   M   Warszawa   NaN     POL       2:41:31
# 465        Kochanek, Krystian   36   M     Warsaw   NaN     POL       2:47:48
# 517       Golaszewski, Michal   40   M  Legionowo   NaN     POL       2:49:00
#
#      Overall  Gender Years Ran     First Name                   BothNames  \
# 213      214     191       NaN  Wojciechowski  [Wojciechowski, Sebastian]
# 465      466     433       NaN       Kochanek        [Kochanek, Krystian]
# 517      518     481       NaN    Golaszewski       [Golaszewski, Michal]
#
#     concat   LastName
# 213   M_33  Sebastian
# 465   M_36   Krystian
# 517   M_40     Michal

# %%
boston[boston.Name.str.contains('Will')]
# Out:
#                       Name  Age M/F           City State Country  \
# 93          Vanos, William   45   M        Orlando    FL     USA
# 199      Guzick, William F   28   M         Boston    MA     USA
# 415        Hartje, William   24   M  Neptune Beach    FL     USA
# 429       Adams, William C   33   M      Arlington    VA     USA
# 456            Cunha, Will   28   M     Pittsburgh    PA     USA
# 526          Swenson, Will   45   M        Andover    MA     USA
# 571  Gates, William E. Jr.   27   M      Maryville    TN     USA
# 711     Swanson, William G   32   M      Riverside    CA     USA
# 814      Williamson, David   49   M         Sutton   NaN     GBR
# 835           Vargas, Will   42   M         Bogota   NaN     COL
# 892           Rivera, Will   46   M  Elizabethtown    KY     USA
# 897    Feldman, William P.   31   M     Greensboro    NC     USA
# 936    Decamps, William M.   30   M        Atlanta    GA     USA
# ...

# %%
boston[boston.Country.str.match('USA')]
# Out:
#                     Name  Age M/F              City State Country  \
# 1         Rupp, Galen      30   M          Portland    OR     USA
# 3       Biwott, Shadrack   32   M     Mammoth Lakes    CA     USA
# 5       Abdirahman, Abdi   40   M           Phoenix    AZ     USA
# 6     Maiyo, Augustus K.   33   M  Colorado Springs    CO     USA
# 8         Puskedra, Luke   27   M            Eugene    OR     USA
# ..                   ...  ...  ..               ...   ...     ...
# 995         Larosa, Mark   38   M     North Andover    MA     USA
# 996  Williamson, Jerry A   43   M           Raleigh    NC     USA
# 997      Mccue, Daniel T   40   M         Arlington    MA     USA
# 998         Larosa, John   35   M           Danbury    CT     USA
# 999       Sanchez, Sam R   35   M          Santa Fe    NM     USA
#
#     Official Time  Overall  Gender  Years Ran  First Name  \
# 1         2:09:58        2       2        NaN        Rupp
# ...

# %%
boston[boston['Years Ran'].notnull()]
# Out:
#                     Name  Age M/F           City State Country Official Time  \
# 4         Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
# 12       Keflezighi, Meb   41   M      San Diego    CA     USA       2:17:00
# 13     Nyasango, Cutbert   34   M         Harara   NaN     ZIM       2:17:40
# 14         Korir, Wesley   34   M         Kitale   NaN     KEN       2:18:14
# 29      Maravilla, Jorge   39   M    Mill Valley    CA     USA       2:24:27
# ..                   ...  ...  ..            ...   ...     ...           ...
# 986        Bretz, Virgil   44   M      Mt. Kisco    NY     USA       2:56:02
# 987     Cucuzzella, Mark   50   M  Shepherdstown    WV     USA       2:56:03
# 988       Carron, John B   46   M      Irvington    NY     USA       2:56:03
# 995         Larosa, Mark   38   M  North Andover    MA     USA       2:56:06
# 996  Williamson, Jerry A   43   M        Raleigh    NC     USA       2:56:06
#
# ...

# %%
dummies = boston['Years Ran'].str.get_dummies(sep=':')

# %%
boston['M/F'].str.get_dummies()
# Out:
#      F  M
# 0    0  1
# 1    0  1
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 995  0  1
# 996  0  1
# 997  0  1
# 998  0  1
# 999  0  1
#
# [1000 rows x 2 columns]

# %%
#boston.insert(boston.columns.get_loc('Years Ran'), 'Ran 2015', dummies['2015'])
boston.insert(boston.columns.get_loc('Years Ran'), 'Ran 2016', dummies['2016'])

# %%
boston.head()
# Out:
#                 Name  Age M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24   M       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30   M       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25   M   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31   M       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender  Ran 2015  Ran 2016 Years Ran First Name  \
# 0        1       1         0         0       NaN      Kirui
# 1        2       2         0         0       NaN       Rupp
# 2        3       3         0         0       NaN      Osako
# 3        4       4         0         0       NaN     Biwott
# 4        5       5         1         0      2015     Chebet
#
#              BothNames concat   LastName
# 0  [ Kirui, Geoffrey ]   M_24  Geoffrey
# 1     [Rupp, Galen   ]   M_30   Galen
# 2    [Osako, Suguru  ]   M_25   Suguru
# ...

# %%
boston[(boston['Ran 2015']==1) & (boston['Ran 2016']==1)].head()
# Out:
#                      Name  Age M/F              City State Country  \
# 14          Korir, Wesley   34   M            Kitale   NaN     KEN
# 30       Ornelas, Zachary   25   M         Ann Arbor    MI     USA
# 31          Ayr, Jason M.   29   M           Allston    MA     USA
# 36  Vangampleare, Stephen   26   M  Colorado Springs    CO     USA
# 56     Boudalia, Said Sr.   48   M           Belluno   NaN     ITA
#
#    Official Time  Overall  Gender  Ran 2015  Ran 2016  Years Ran  \
# 14       2:18:14       15      15         1         1  2015:2016
# 30       2:24:40       31      28         1         1  2015:2016
# 31       2:24:49       32      29         1         1  2015:2016
# 36       2:25:35       37      33         1         1  2015:2016
# 56       2:30:11       57      51         1         1  2015:2016
#
#       First Name                BothNames concat  LastName
# 14         Korir          [Korir, Wesley]   M_34    Wesley
# ...

# %%
boston['Ran 2015'].all()
# Out:
# False

# %%
s
# Out:
# '  the name is: BOND \t JAMES BOND \n\n'

# %%
s = 'Welcome to the text manipulation section. This section is about text.'

# %%
s.replace('Welcome', 'Wilkommen')
# Out:
# 'Wilkommen to the text manipulation section. This section is about text.'

# %%
boston.sample(10)
# Out:
#                           Name  Age M/F            City State Country  \
# 356  Castillo, Franklin A. Sr.   32   M  Doral, Florida   NaN     PAN
# 781                   O, Loc M   40   M    Williamsburg    PA     USA
# 631               Stewart, Ben   26   M     Minneapolis    MN     USA
# 691              Smith, Adam D   30   M      Pittsburgh    PA     USA
# 740               Caputo, Mike   26   M   Staten Island    NY     USA
# 120               Sherf, Aaron   27   M          Norman    OK     USA
# 284            Roberts, Duncan   41   M        Portland    OR     USA
# 396     Vanderwoude, Darryl E.   29   M        Edmonton    AB     CAN
# 300      McGettigan, Joshua D.   30   M          London   NaN     GBR
# 578           Lemelman, Daniel   26   M     Monroe Twp.    NJ     USA
#
#     Official Time  Overall  Gender  Ran 2015  Ran 2016  Years Ran  \
# 356       2:45:37      357     330         0         0        NaN
# ...

# %%
boston['M/F'] = boston['M/F'].str.replace('M', 'male').str.replace('F', 'female')

# %%
boston.sample(10)
# Out:
#                                Name  Age     M/F          City State Country  \
# 631                    Stewart, Ben   26    male   Minneapolis    MN     USA
# 398               Cyganik, Jonathan   24    male        Boston    MA     USA
# 496                 Scudder, John L   40    male           Apo    AE     USA
# 733  Castano Gonzalez, Angel U. Sr.   41    male      Medellin   NaN     COL
# 192                   Craigie, Eoin   38    male      Montreal    QC     CAN
# 82                  Klecker, Jack R   25    male        Boston    MA     USA
# 77            Remillard, Charles A.   23    male      Brooklyn    NY     USA
# 230                   Corno, Hilary   41  female     Encinitas    CA     USA
# 850                 Langerak, Bruce   45    male  Byron Center    MI     USA
# 745                  Totman, Andrew   36    male     Stallings    NC     USA
#
#     Official Time  Overall  Gender  Ran 2015  Ran 2016 Years Ran  \
# ...

# %%
boston.Country.str.replace('Usa', 'United States', case=False)
# Out:
# 0                KEN
# 1      United States
# 2                JPN
# 3      United States
# 4                KEN
#            ...
# 995    United States
# 996    United States
# 997    United States
# 998    United States
# 999    United States
# Name: Country, Length: 1000, dtype: object

# %%
boston.Name[boston.Name.str.contains(pat=r'[wW]ill', regex=True)]
# Out:
# 93            Vanos, William
# 199        Guzick, William F
# 415          Hartje, William
# 429         Adams, William C
# 456              Cunha, Will
# 526            Swenson, Will
# 571    Gates, William E. Jr.
# 711       Swanson, William G
# 814        Williamson, David
# 835             Vargas, Will
# 892             Rivera, Will
# 897      Feldman, William P.
# 936      Decamps, William M.
# 939        Versen, William R
# 996      Williamson, Jerry A
# Name: Name, dtype: object

# %%
boston.Name[boston.Name.str.contains(pat=r',\s[wW]ill\b', regex=True)]
# Out:
# 456      Cunha, Will
# 526    Swenson, Will
# 835     Vargas, Will
# 892     Rivera, Will
# Name: Name, dtype: object

# %%
boston['Official Time'].head()
# Out:
# 0    2:09:37
# 1    2:09:58
# 2    2:10:28
# 3    2:12:08
# 4    2:12:35
# Name: Official Time, dtype: object

# %%
boston['Official Time'].str.replace(r"(\d+):(\d+):(\d+)", r"\1 hours, \2 minutes, and \3 seconds")
# Out:
# /var/folders/cw/s321vfbx6j78jd3lsjfcsdyw0000gn/T/ipykernel_16172/3942743455.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   boston['Official Time'].str.replace(r"(\d+):(\d+):(\d+)", r"\1 hours, \2 minutes, and \3 seconds")
# 0      2 hours, 09 minutes, and 37 seconds
# 1      2 hours, 09 minutes, and 58 seconds
# 2      2 hours, 10 minutes, and 28 seconds
# 3      2 hours, 12 minutes, and 08 seconds
# 4      2 hours, 12 minutes, and 35 seconds
#                       ...
# 995    2 hours, 56 minutes, and 06 seconds
# 996    2 hours, 56 minutes, and 06 seconds
# 997    2 hours, 56 minutes, and 06 seconds
# 998    2 hours, 56 minutes, and 07 seconds
# 999    2 hours, 56 minutes, and 08 seconds
# Name: Official Time, Length: 1000, dtype: object

# %%
dupa
# Out:
# 0      2:09:37
# 1      2:09:58
# 2      2:10:28
# 3      2:12:08
# 4      2:12:35
#         ...
# 995    2:56:06
# 996    2:56:06
# 997    2:56:06
# 998    2:56:07
# 999    2:56:08
# Name: Official Time, Length: 1000, dtype: object

# %%
final_times = boston['Official Time'].str.split(r':', expand=True)

# %%
final_times['total'] = final_times[0].astype(int) * 60 * 60 + final_times[1].astype(int) * 60 + final_times[2].astype(int)

# %%
final_times['total'].head()
# Out:
# 0    7777
# 1    7798
# 2    7828
# 3    7928
# 4    7955
# Name: total, dtype: int64

# %%
boston['total'] = final_times['total']

# %%
boston.head()
# Out:
#                 Name  Age   M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24  male       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30  male       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25  male   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32  male  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31  male       Marakwet   NaN     KEN       2:12:35
#
#    Overall  Gender  Ran 2015  Ran 2016 Years Ran First Name  \
# 0        1       1         0         0       NaN      Kirui
# 1        2       2         0         0       NaN       Rupp
# 2        3       3         0         0       NaN      Osako
# 3        4       4         0         0       NaN     Biwott
# 4        5       5         1         0      2015     Chebet
#
#              BothNames concat   LastName  total
# 0  [ Kirui, Geoffrey ]   M_24  Geoffrey    7777
# 1     [Rupp, Galen   ]   M_30   Galen      7798
# ...

# %%
boston.groupby('Ran 2016')['total'].mean()
# Out:
# Ran 2016
# 0     9966.195739
# 1    10043.120482
# Name: total, dtype: float64

# %%
boston.insert(boston.columns.get_loc('Official Time')+1, 'Total Seconds', final_times.total)

# %%
boston.head()
# Out:
#                 Name  Age   M/F           City State Country Official Time  \
# 0   Kirui, Geoffrey    24  male       Keringet   NaN     KEN       2:09:37
# 1     Rupp, Galen      30  male       Portland    OR     USA       2:09:58
# 2    Osako, Suguru     25  male   Machida-City   NaN     JPN       2:10:28
# 3   Biwott, Shadrack   32  male  Mammoth Lakes    CA     USA       2:12:08
# 4     Chebet, Wilson   31  male       Marakwet   NaN     KEN       2:12:35
#
#    Total Seconds  Overall  Gender  Ran 2015  Ran 2016 Years Ran First Name  \
# 0           7777        1       1         0         0       NaN      Kirui
# 1           7798        2       2         0         0       NaN       Rupp
# 2           7828        3       3         0         0       NaN      Osako
# 3           7928        4       4         0         0       NaN     Biwott
# 4           7955        5       5         1         0      2015     Chebet
#
#              BothNames concat   LastName  total
# ...

# %%
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb Cell 92 line 1
# ----> <a href='vscode-notebook-cell:/Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb#Y160sZmlsZQ%3D%3D?line=0'>1</a> from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb Cell 93 line 1
# ----> <a href='vscode-notebook-cell:/Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb#Y161sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
games.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb Cell 94 line 1
# ----> <a href='vscode-notebook-cell:/Users/bartoszpiechnik/Desktop/Programming/repos/notebooks/sandbox/strings.ipynb#Y162sZmlsZQ%3D%3D?line=0'>1</a> games.head()
#
# NameError: name 'games' is not defined
