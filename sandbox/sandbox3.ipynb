# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.1'

# %%
eng = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/eng.csv")
state = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/state.csv")
liberal = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/liberal_arts.csv")
ivies = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/ivies.csv")
party = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/party.csv")

# %%
ivies.head()
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00

# %%
liberal.head()
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
# 2      Amherst College  Liberal Arts            $54,500.00
# 3    Lafayette College  Liberal Arts            $53,900.00
# 4      Bowdoin College  Liberal Arts            $48,100.00
#
#   Mid-Career Median Salary
# 0             $110,000.00
# 1             $108,000.00
# 2             $107,000.00
# 3             $107,000.00
# 4             $107,000.00

# %%
state.head()
# Out:
#                                       School Name School Type  \
# 0              University of California, Berkeley       State
# 1                    University of Virginia (UVA)       State
# 2                        Cal Poly San Luis Obispo       State
# 3  University of California at Los Angeles (UCLA)       State
# 4      University of California, San Diego (UCSD)       State
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 1            $52,700.00              $103,000.00
# 2            $57,200.00              $101,000.00
# 3            $52,600.00              $101,000.00
# 4            $51,100.00              $101,000.00

# %%
party.head()
# Out:
#                                          School Name School Type  \
# 0  University of Illinois at Urbana-Champaign (UIUC)       Party
# 1               University of Maryland, College Park       Party
# 2     University of California, Santa Barbara (UCSB)       Party
# 3                  University of Texas (UT) - Austin       Party
# 4      State University of New York (SUNY) at Albany       Party
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $52,900.00               $96,100.00
# 1            $52,000.00               $95,000.00
# 2            $50,500.00               $95,000.00
# 3            $49,700.00               $93,900.00
# 4            $44,500.00               $92,200.00

# %%
eng.head()
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $72,200.00              $126,000.00
# 1            $75,500.00              $123,000.00
# 2            $71,800.00              $122,000.00
# 3            $62,400.00              $114,000.00
# 4            $62,200.00              $114,000.00

# %%
dfs = [state, eng, liberal, ivies, party]

# %%
for df in dfs:
    print(df.shape)
# Out:
# (175, 4)
# (19, 4)
# (47, 4)
# (8, 4)
# (20, 4)

# %%
pd.concat([ivies, eng]).reset_index(drop=True)
# Out:
#                                           School Name  School Type  \
# 0                                   Dartmouth College   Ivy League
# 1                                Princeton University   Ivy League
# 2                                     Yale University   Ivy League
# 3                                  Harvard University   Ivy League
# 4                          University of Pennsylvania   Ivy League
# 5                                  Cornell University   Ivy League
# 6                                    Brown University   Ivy League
# 7                                 Columbia University   Ivy League
# 8         Massachusetts Institute of Technology (MIT)  Engineering
# 9            California Institute of Technology (CIT)  Engineering
# 10                                Harvey Mudd College  Engineering
# 11       Polytechnic University of New York, Brooklyn  Engineering
# 12                                       Cooper Union  Engineering
# ...

# %%
pd.concat(dfs)
# Out:
#                                        School Name School Type  \
# 0               University of California, Berkeley       State
# 1                     University of Virginia (UVA)       State
# 2                         Cal Poly San Luis Obispo       State
# 3   University of California at Los Angeles (UCLA)       State
# 4       University of California, San Diego (UCSD)       State
# ..                                             ...         ...
# 15               University of New Hampshire (UNH)       Party
# 16                  West Virginia University (WVU)       Party
# 17                         University of Tennessee       Party
# 18                                 Ohio University       Party
# 19                  Florida State University (FSU)       Party
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $59,900.00              $112,000.00
# 1             $52,700.00              $103,000.00
# 2             $57,200.00              $101,000.00
# ...

# %%
set(party['School Name']).difference(state['School Name'])
# Out:
# {'Randolph-Macon College'}

# %%
aaa = pd.Series(['a', 'b', 'c'])

# %%
bbb = pd.Series(['a', 'b', 'd'])

# %%
set(aaa).difference(bbb)
# Out:
# {'c'}

# %%
s1 = pd.Series([1, 2, 3, 4])
s2 = pd.Series([3, 4, 5, 6])

# %%
set1 = set(s1)
set2 = set(s2)

# %%
diff = set1.difference(set2)

# %%
diff
# Out:
# {1, 2}

# %%
diff2 = set2.difference(set1)

# %%
diff2
# Out:
# {5, 6}

# %%
schools = pd.concat(dfs).drop_duplicates(subset='School Name')

# %%
schools.head()
# Out:
#                                       School Name School Type  \
# 0              University of California, Berkeley       State
# 1                    University of Virginia (UVA)       State
# 2                        Cal Poly San Luis Obispo       State
# 3  University of California at Los Angeles (UCLA)       State
# 4      University of California, San Diego (UCSD)       State
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 1            $52,700.00              $103,000.00
# 2            $57,200.00              $101,000.00
# 3            $52,600.00              $101,000.00
# 4            $51,100.00              $101,000.00

# %%
new_df = pd.concat(dfs, ignore_index=True).drop_duplicates(subset='School Name')
new_df
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 244                              Harvard University  Ivy League
# 245                      University of Pennsylvania  Ivy League
# 246                              Cornell University  Ivy League
# 247                                Brown University  Ivy League
# 248                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
mdf = pd.concat([ivies, eng], keys=['ivy', 'engineering'])

# %%
mdf.loc[('ivy', 5)]
# Out:
# School Name                 Cornell University
# School Type                         Ivy League
# Starting Median Salary             $60,300.00
# Mid-Career Median Salary          $110,000.00
# Name: (ivy, 5), dtype: object

# %%
eng4 = eng.copy()

# %%
eng4['STEM'] = True

# %%
dff_inner = pd.concat([ivies, eng4], join='inner')

# %%
dff_inner
# Out:
#                                           School Name  School Type  \
# 0                                   Dartmouth College   Ivy League
# 1                                Princeton University   Ivy League
# 2                                     Yale University   Ivy League
# 3                                  Harvard University   Ivy League
# 4                          University of Pennsylvania   Ivy League
# 5                                  Cornell University   Ivy League
# 6                                    Brown University   Ivy League
# 7                                 Columbia University   Ivy League
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# ...

# %%
dff_outer = pd.concat([ivies, eng4], join='outer')
dff_outer
# Out:
#                                           School Name  School Type  \
# 0                                   Dartmouth College   Ivy League
# 1                                Princeton University   Ivy League
# 2                                     Yale University   Ivy League
# 3                                  Harvard University   Ivy League
# 4                          University of Pennsylvania   Ivy League
# 5                                  Cornell University   Ivy League
# 6                                    Brown University   Ivy League
# 7                                 Columbia University   Ivy League
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# ...

# %%
df2 = pd.concat([liberal, state]).reset_index(drop=True)
df2.loc[:, 'Starting Median Salary'] = df2['Starting Median Salary'].apply(lambda x: int(x[1:].replace(',', '')[:-4]))
# Out:
# /var/folders/cw/s321vfbx6j78jd3lsjfcsdyw0000gn/T/ipykernel_2138/3041392681.py:2: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df2.loc[:, 'Starting Median Salary'] = df2['Starting Median Salary'].apply(lambda x: int(x[1:].replace(',', '')[:-4]))

# %%
df2['Starting Median Salary'].mean()
# Out:
# 44469.36936936937

# %%
liberal3 = liberal[:3]
liberal3

#liberal3 = liberal.copy().sort_values(by=['Mid-Career Median Salary'], ascending=False)
#liberal3
# Out:
#            School Name   School Type Starting Median Salary  \
# 0  Bucknell University  Liberal Arts            $54,100.00
# 1   Colgate University  Liberal Arts            $52,800.00
# 2      Amherst College  Liberal Arts            $54,500.00
#
#   Mid-Career Median Salary
# 0             $110,000.00
# 1             $108,000.00
# 2             $107,000.00

# %%
state3 = state[:3]
state3
# Out:
#                           School Name School Type Starting Median Salary  \
# 0  University of California, Berkeley       State            $59,900.00
# 1        University of Virginia (UVA)       State            $52,700.00
# 2            Cal Poly San Luis Obispo       State            $57,200.00
#
#   Mid-Career Median Salary
# 0             $112,000.00
# 1             $103,000.00
# 2             $101,000.00

# %%
my_df = pd.concat([liberal3[['School Name', 'Mid-Career Median Salary']], state3[['School Name', 'Mid-Career Median Salary']]], axis=1, keys=['Liberal Arts', 'State'])
my_df
# Out:
#           Liberal Arts                           \
#            School Name Mid-Career Median Salary
# 0  Bucknell University             $110,000.00
# 1   Colgate University             $108,000.00
# 2      Amherst College             $107,000.00
#
#                                 State
#                           School Name Mid-Career Median Salary
# 0  University of California, Berkeley             $112,000.00
# 1        University of Virginia (UVA)             $103,000.00
# 2            Cal Poly San Luis Obispo             $101,000.00

# %%
regions = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/regions.csv")
regions.head()
# Out:
#                                     School Name        Region
# 0   Massachusetts Institute of Technology (MIT)  Northeastern
# 1      California Institute of Technology (CIT)    California
# 2                           Harvey Mudd College    California
# 3  Polytechnic University of New York, Brooklyn  Northeastern
# 4                                  Cooper Union  Northeastern

# %%
schools.head()
# Out:
#                                       School Name School Type  \
# 0              University of California, Berkeley       State
# 1                    University of Virginia (UVA)       State
# 2                        Cal Poly San Luis Obispo       State
# 3  University of California at Los Angeles (UCLA)       State
# 4      University of California, San Diego (UCSD)       State
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 1            $52,700.00              $103,000.00
# 2            $57,200.00              $101,000.00
# 3            $52,600.00              $101,000.00
# 4            $51,100.00              $101,000.00

# %%
comb = pd.merge(left=schools, right=regions, left_on='School Name', right_on='School Name')

# %%
comb.head(10)
# Out:
#                                          School Name School Type  \
# 0                 University of California, Berkeley       State
# 1                       University of Virginia (UVA)       State
# 2                           Cal Poly San Luis Obispo       State
# 3     University of California at Los Angeles (UCLA)       State
# 4         University of California, San Diego (UCSD)       State
# 5                    University of California, Davis       State
# 6             University of Colorado - Boulder (UCB)       State
# 7             University of California, Irvine (UCI)       State
# 8  University of Illinois at Urbana-Champaign (UIUC)       State
# 9  University of Illinois at Urbana-Champaign (UIUC)       State
#
#   Starting Median Salary Mid-Career Median Salary      Region
# 0            $59,900.00              $112,000.00   California
# 1            $52,700.00              $103,000.00     Southern
# 2            $57,200.00              $101,000.00   California
# ...

# %%
mid_career = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/mid_career_salaries.csv")

# %%
mid_career.head()
# Out:
#                                     school_name  \
# 0   Massachusetts Institute of Technology (MIT)
# 1      California Institute of Technology (CIT)
# 2                           Harvey Mudd College
# 3  Polytechnic University of New York, Brooklyn
# 4                                  Cooper Union
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                       $76,800.00                        $99,200.00
# 1                               NaN                      $104,000.00
# 2                               NaN                       $96,000.00
# 3                       $66,800.00                        $94,300.00
# 4                               NaN                       $80,200.00
#
#   Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                      $168,000.00                       $220,000.00
# 1                      $161,000.00                                NaN
# ...

# %%
schools.head()
# Out:
#                                       School Name School Type  \
# 0              University of California, Berkeley       State
# 1                    University of Virginia (UVA)       State
# 2                        Cal Poly San Luis Obispo       State
# 3  University of California at Los Angeles (UCLA)       State
# 4      University of California, San Diego (UCSD)       State
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 1            $52,700.00              $103,000.00
# 2            $57,200.00              $101,000.00
# 3            $52,600.00              $101,000.00
# 4            $51,100.00              $101,000.00

# %%
mid_career.rename(columns={'school_name': 'School Name'}, inplace=True)

# %%
mmm = pd.merge(schools, mid_career)

# %%
mmm
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 264                              Harvard University  Ivy League
# 265                      University of Pennsylvania  Ivy League
# 266                              Cornell University  Ivy League
# 267                                Brown University  Ivy League
# 268                             Columbia University  Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
a = {1,2,3}
b = {4,5,2}
a.union(b)
# Out:
# {1, 2, 3, 4, 5}

# %%
c = (0,0,1,3)

# %%
c
# Out:
# (0, 0, 1, 3)

# %%
d = {0,0,1,2}

# %%
d
# Out:
# {0, 1, 2}

# %%
type(d)
# Out:
# set

# %%
regions.join()

# %%
dfm = pd.merge(liberal, regions)

# %%
dfm['Region'].value_counts()
# Out:
# Northeastern    25
# Midwestern       8
# Western          7
# Southern         5
# California       3
# Name: Region, dtype: int64

# %%
mid_career
# Out:
#                                       School Name  \
# 0     Massachusetts Institute of Technology (MIT)
# 1        California Institute of Technology (CIT)
# 2                             Harvey Mudd College
# 3    Polytechnic University of New York, Brooklyn
# 4                                    Cooper Union
# ..                                            ...
# 264                  Austin Peay State University
# 265                    Pittsburg State University
# 266                      Southern Utah University
# 267           Montana State University - Billings
# 268                  Black Hills State University
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                         $76,800.00                        $99,200.00
# 1                                 NaN                      $104,000.00
# 2                                 NaN                       $96,000.00
# 3                         $66,800.00                        $94,300.00
# ...

# %%
mid_career.set_index('School Name', inplace=True)

# %%
mid_career
# Out:
#                                              Mid-Career 10th Percentile Salary  \
# School Name
# Massachusetts Institute of Technology (MIT)                        $76,800.00
# California Institute of Technology (CIT)                                   NaN
# Harvey Mudd College                                                        NaN
# Polytechnic University of New York, Brooklyn                       $66,800.00
# Cooper Union                                                               NaN
# ...                                                                        ...
# Austin Peay State University                                       $32,200.00
# Pittsburg State University                                         $25,600.00
# Southern Utah University                                           $30,700.00
# Montana State University - Billings                                $22,600.00
# Black Hills State University                                       $27,000.00
#
# ...

# %%
fff = pd.merge(dfm, mid_career, left_on='School Name', right_index=True)

# %%
fff
# Out:
#                                       School Name   School Type  \
# 0                             Bucknell University  Liberal Arts
# 1                              Colgate University  Liberal Arts
# 2                                 Amherst College  Liberal Arts
# 3                               Lafayette College  Liberal Arts
# 4                                 Bowdoin College  Liberal Arts
# 5                       College of the Holy Cross  Liberal Arts
# 6                              Occidental College  Liberal Arts
# 7                   Washington and Lee University  Liberal Arts
# 8                              Swarthmore College  Liberal Arts
# 9                                Davidson College  Liberal Arts
# 10                               Carleton College  Liberal Arts
# 11                               Williams College  Liberal Arts
# 12                                 Pomona College  Liberal Arts
# 13  Wesleyan University (Middletown, Connecticut)  Liberal Arts
# ...
