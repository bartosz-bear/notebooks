# %%
import numpy as np
import pandas as pd

players = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/soccer.csv")

# %%
players.dtypes.value_counts()
# Out:
# int64      10
# object      5
# float64     2
# dtype: int64

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players[players.market_value > 40]
# Out:
#                   name               club  age position  position_cat  \
# 0       Alexis Sanchez            Arsenal   28       LW             1
# 1           Mesut Ozil            Arsenal   28       AM             1
# 96         Eden Hazard            Chelsea   26       LW             1
# 97         Diego Costa            Chelsea   28       CF             1
# 108     N%27Golo Kante            Chelsea   26       DM             2
# 218  Philippe Coutinho          Liverpool   25       AM             1
# 244    Kevin De Bruyne    Manchester+City   26       AM             1
# 245      Sergio Aguero    Manchester+City   29       CF             1
# 246    Raheem Sterling    Manchester+City   22       LW             1
# 264      Romelu Lukaku  Manchester+United   24       CF             1
# 267         Paul Pogba  Manchester+United   24       CM             2
# 380          Dele Alli          Tottenham   21       CM             2
# ...

# %%
players.position.isin(['LB', 'CB', 'RB'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 460    False
# 461     True
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
players.loc[players.position.isin(['LB', 'RB', 'CB'])]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# 5      Hector Bellerin   Arsenal   22       RB             3          30.0
# 7        Nacho Monreal   Arsenal   31       LB             3          13.0
# 8     Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 17    Gabriel Paulista   Arsenal   26       CB             3          13.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461     Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462          Sam Byram  West+Ham   23       RB             3           4.5
#
# ...

# %%
players.market_value.between(40, 50, inclusive='neither')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
players[players.market_value.between(40, 50, inclusive='neither')]
# Out:
#                   name             club  age position  position_cat  \
# 218  Philippe Coutinho        Liverpool   25       AM             1
# 246    Raheem Sterling  Manchester+City   22       LW             1
# 380          Dele Alli        Tottenham   21       CM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 218          45.0        2958        9.0  30.80%         171       3
# 246          45.0        2074        8.0   3.80%         149       1
# 380          45.0        4626        9.5  38.60%         225       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 218      Brazil            0        3       10         1            0
# 246     England            0        2       11         1            0
# 380     England            0        1       17         1            0

# %%
s1 = pd.Series(data=[False, True, True], index=['c', 'b', 'a'])
s2 = pd.Series(data=[True, False, False], index=['a', 'b', 'c'])

s1 & s2
# Out:
# a     True
# b    False
# c    False
# dtype: bool

# %%
True ^ True
# Out:
# False

# %%
a = True

# %%
b = ~a

# %%
b
# Out:
# -2

# %%
b == False
# Out:
# False

# %%
b == -2
# Out:
# True

# %%
ser = pd.Series([True, False, True])
ser
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
~ser
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
players[(players.position == 'LB') &
        (players.age <= 25) &
        (players.market_value >= 10) &
        ~(players.club.isin(['Tottenham', 'Arsenal']))]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %%
arsenal_players = players.club == 'Arsenal'

# %%
players[arsenal_players]
# Out:
#                        name     club  age position  position_cat  \
# 0            Alexis Sanchez  Arsenal   28       LW             1
# 1                Mesut Ozil  Arsenal   28       AM             1
# 2                 Petr Cech  Arsenal   35       GK             4
# 3              Theo Walcott  Arsenal   28       RW             1
# 4         Laurent Koscielny  Arsenal   31       CB             3
# 5           Hector Bellerin  Arsenal   22       RB             3
# 6            Olivier Giroud  Arsenal   30       CF             1
# 7             Nacho Monreal  Arsenal   31       LB             3
# 8          Shkodran Mustafi  Arsenal   25       CB             3
# 9                Alex Iwobi  Arsenal   21       LW             1
# 10             Granit Xhaka  Arsenal   24       DM             2
# 11             Granit Xhaka  Arsenal   24       DM             2
# 12  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# ...

# %%
right_backs = players.position == 'RB'
players[right_backs]
# Out:
#                        name               club  age position  position_cat  \
# 5           Hector Bellerin            Arsenal   22       RB             3
# 27           Carl Jenkinson            Arsenal   25       RB             3
# 38               Adam Smith        Bournemouth   26       RB             3
# 40            Simon Francis        Bournemouth   32       RB             3
# 61                    Bruno  Brighton+and+Hove   36       RB             1
# 63            Liam Rosenior  Brighton+and+Hove   33       RB             3
# 83           Matthew Lowton            Burnley   28       RB             3
# 100       Cesar Azpilicueta            Chelsea   27       RB             3
# 124               Joel Ward     Crystal+Palace   27       RB             3
# 129            Martin Kelly     Crystal+Palace   27       RB             3
# 139          Seamus Coleman            Everton   28       RB             3
# ...

# %%
chelsea_gk = (players.club == 'Chelsea') & (players.position == 'GK')
players[chelsea_gk]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 102  Thibaut Courtois  Chelsea   25       GK             4          40.0
# 109   Willy Caballero  Chelsea   35       GK             4           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 102        1260        5.5  18.50%         141       2     Belgium
# 109         542        5.0   0.20%          64       3   Argentina
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 102            0        3        5         1            0
# 109            0        6        5         1            0

# %%
players[arsenal_players & right_backs | chelsea_gk]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 5     Hector Bellerin  Arsenal   22       RB             3          30.0
# 27     Carl Jenkinson  Arsenal   25       RB             3           5.0
# 102  Thibaut Courtois  Chelsea   25       GK             4          40.0
# 109   Willy Caballero  Chelsea   35       GK             4           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 5          1675        6.0  13.70%         119       2       Spain
# 27          561        4.5   0.40%           2       1     England
# 102        1260        5.5  18.50%         141       2     Belgium
# 109         542        5.0   0.20%          64       3   Argentina
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 27             0        3        1         1            0
# 102            0        3        5         1            0
# ...

# %%
english = players.nationality == 'England'
expensive = players.market_value > 2 * players.market_value.mean()
special = (players.page_views > 4000) ^ (players.new_signing == 1)
subset = players[english & expensive & special]

# %%
subset
# Out:
#             name             club  age position  position_cat  market_value  \
# 256  John Stones  Manchester+City   23       CB             3          35.0
# 380    Dele Alli        Tottenham   21       CM             2          45.0
# 381   Harry Kane        Tottenham   23       CF             1          60.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 256        1078        5.5   2.30%          59       1     England
# 380        4626        9.5  38.60%         225       1     England
# 381        4161       12.5  35.10%         224       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 256            0        2       11         1            1
# 380            0        1       17         1            0
# 381            0        2       17         1            0

# %% [markdown]
# chelsea23_under = (players.clue == 'Chelsea') & (players.age.le(23))

# %%
chelsea23_under = (players.club == 'Chelsea') & (players.age.le(23))
players.loc[chelsea23_under]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 110   Michy Batshuayi  Chelsea   23       CF             1          25.0
# 111        Kurt Zouma  Chelsea   22       CB             3          15.0
# 112            Kenedy  Chelsea   21       LB             3           7.0
# 115  Tiemoue Bakayoko  Chelsea   22       DM             2          16.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 110        1162        8.5   1.60%          48       2     Belgium
# 111         723        5.5   0.80%          15       2      France
# 112         566        5.0   0.10%           3       3      Brazil
# 115        1011        5.0   1.60%           0       2      France
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 110            0        2        5         1            1
# 111            0        2        5         1            0
# 112            0        1        5         1            0
# ...

# %%
players.loc[chelsea23_under, ['name', 'market_value', 'position']]
# Out:
#                  name  market_value position
# 110   Michy Batshuayi          25.0       CF
# 111        Kurt Zouma          15.0       CB
# 112            Kenedy           7.0       LB
# 115  Tiemoue Bakayoko          16.0       DM

# %%
p_cols = players.columns.str.startswith('p')

# %%
p_cols
# Out:
# array([False, False, False,  True,  True, False,  True, False, False,
#        False, False, False, False, False, False, False, False])

# %%
players.loc[chelsea23_under, p_cols]
# Out:
#     position  position_cat  page_views
# 110       CF             1        1162
# 111       CB             3         723
# 112       LB             3         566
# 115       DM             2        1011

# %%
#names = ['Petr Czech', 'Mesut Ozil', 'Alexis Sanchez']
#attributes = ['age', 'market_value', 'page_views']
#players.set_index('name').lookup(names, attributes)

# %%
players[players['name'].duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 30             Granit Xhaka  Arsenal   24      NaN             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
# 30           NaN        1815        5.5   2.00%          85       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0
# ...

# %%
players.drop_duplicates(inplace=True)

# %%
#names = ['Petr Czech', 'Mesut Ozil', 'Alexis Sanchez']
#attributes = ['age', 'market_value', 'page_views']
#players.set_index('name').lookup(names, attributes)

# %%
players[players['name'].duplicated()]
# Out:
#             name     club  age position  position_cat  market_value  \
# 30  Granit Xhaka  Arsenal   24      NaN             2           NaN
#
#     page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 30        1815        5.5   2.00%          85       2  Switzerland
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# 30            0        2        1         1            0

# %%
players.drop(30, inplace=True)

# %%
players[players['name'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, club, age, position, position_cat, market_value, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing]
# Index: []

# %%
names = ['Petr Cech', 'Mesut Ozil', 'Alexis Sanchez']
attributes = ['age', 'market_value', 'page_views']
players.set_index('name').lookup(names, attributes)
# Out:
# /var/folders/cw/s321vfbx6j78jd3lsjfcsdyw0000gn/T/ipykernel_93079/1917241057.py:3: FutureWarning: The 'lookup' method is deprecated and will be removed in a future version. You can use DataFrame.melt and DataFrame.loc as a substitute.
#   players.set_index('name').lookup(names, attributes)
# array([  35.,   50., 4329.])

# %%
players[:5]
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.set_index('name', inplace=True)

# %%
players.head()
# Out:
#                       club  age position  position_cat  market_value  \
# name
# Alexis Sanchez     Arsenal   28       LW             1          65.0
# Mesut Ozil         Arsenal   28       AM             1          50.0
# Petr Cech          Arsenal   35       GK             4           7.0
# Theo Walcott       Arsenal   28       RW             1          20.0
# Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#                    page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Alexis Sanchez           4329       12.0  17.10%         264       3
# Mesut Ozil               4395        9.5   5.60%         167       2
# Petr Cech                1529        5.5   5.90%         134       2
# Theo Walcott             2393        7.5   1.50%         122       1
# Laurent Koscielny         912        6.0   0.70%         121       2
#
#                       nationality  new_foreign  age_cat  club_id  big_club  \
# name
# ...

# %%
players.sort_index(inplace=True)

# %%
players.sort_index(axis=1)
# Out:
#                     age  age_cat  big_club            club  club_id  \
# name
# Aaron Cresswell      27        3         0        West+Ham       20
# Aaron Lennon         30        4         0         Everton        7
# Aaron Mooy           26        3         0    Huddersfield        8
# Aaron Ramsey         26        3         1         Arsenal        1
# Abdoulaye Doucoure   24        2         0         Watford       18
# ...                 ...      ...       ...             ...      ...
# Yohan Cabaye         31        4         0  Crystal+Palace        6
# YounÃ¨s Kaboul       31        4         0         Watford       18
# Ã‰tienne Capoue      29        4         0         Watford       18
# Ã€ngel Rangel        34        6         0         Swansea       16
# Åukasz FabiaÅ„ski   32        5         0         Swansea       16
#
#                     fpl_points fpl_sel  fpl_value  market_value nationality  \
# name
# ...

# %%
players.head()
# Out:
#                             club  age position  position_cat  market_value  \
# name
# Aaron Cresswell         West+Ham   27       LB             3          12.0
# Aaron Lennon             Everton   30       RW             1           5.0
# Aaron Mooy          Huddersfield   26       CM             2           5.0
# Aaron Ramsey             Arsenal   26       CM             2          35.0
# Abdoulaye Doucoure       Watford   24       CM             2           6.0
#
#                     page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Aaron Cresswell            380        5.0   1.30%          60       1
# Aaron Lennon               504        5.5   0.20%          22       1
# Aaron Mooy                 588        5.5   2.50%           0       4
# Aaron Ramsey              1040        7.0   5.10%          56       1
# Abdoulaye Doucoure         124        5.0   0.00%          38       2
#
#                    nationality  new_foreign  age_cat  club_id  big_club  \
# ...

# %%
players.reset_index(inplace=True)

# %%
players.head()
# Out:
#                  name          club  age position  position_cat  market_value  \
# 0     Aaron Cresswell      West+Ham   27       LB             3          12.0
# 1        Aaron Lennon       Everton   30       RW             1           5.0
# 2          Aaron Mooy  Huddersfield   26       CM             2           5.0
# 3        Aaron Ramsey       Arsenal   26       CM             2          35.0
# 4  Abdoulaye Doucoure       Watford   24       CM             2           6.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0         380        5.0   1.30%          60       1     England            0
# 1         504        5.5   0.20%          22       1     England            0
# 2         588        5.5   2.50%           0       4   Australia            0
# 3        1040        7.0   5.10%          56       1       Wales            0
# 4         124        5.0   0.00%          38       2      France            0
#
# ...

# %%
players_lite = players.iloc[:4, :4]

# %%
players_lite
# Out:
#               name          club  age position
# 0  Aaron Cresswell      West+Ham   27       LB
# 1     Aaron Lennon       Everton   30       RW
# 2       Aaron Mooy  Huddersfield   26       CM
# 3     Aaron Ramsey       Arsenal   26       CM

# %%
players_lite.reindex(index=[2,1,3,0], columns=['age', 'name', 'position', 'club'])
# Out:
#    age             name position          club
# 2   26       Aaron Mooy       CM  Huddersfield
# 1   30     Aaron Lennon       RW       Everton
# 3   26     Aaron Ramsey       CM       Arsenal
# 0   27  Aaron Cresswell       LB      West+Ham

# %%
players.reindex(index=[2,1,3,0]).sort_index(axis=1)
# Out:
#    age  age_cat  big_club          club  club_id  fpl_points fpl_sel  \
# 2   26        3         0  Huddersfield        8           0   2.50%
# 1   30        4         0       Everton        7          22   0.20%
# 3   26        3         1       Arsenal        1          56   5.10%
# 0   27        3         0      West+Ham       20          60   1.30%
#
#    fpl_value  market_value             name nationality  new_foreign  \
# 2        5.5           5.0       Aaron Mooy   Australia            0
# 1        5.5           5.0     Aaron Lennon     England            0
# 3        7.0          35.0     Aaron Ramsey       Wales            0
# 0        5.0          12.0  Aaron Cresswell     England            0
#
#    new_signing  page_views position  position_cat  region
# 2            0         588       CM             2       4
# 1            0         504       RW             1       1
# 3            0        1040       CM             2       1
# ...

# %%
iter([1,2,3])

# %%
players.sort_values(by='age').iat[0,0]
# Out:
# 'Ben Woodburn'

# %%
players.set_index('club', inplace=True, drop=False)#.sort_index(inplace=True)

# %%
players.sort_index(inplace=True)

# %%
players.head()
# Out:
#                       name     club  age position  position_cat  market_value  \
# club
# Arsenal      Santi Cazorla  Arsenal   32       CM             2          12.0
# Arsenal        Lucas Perez  Arsenal   28       CF             1          15.0
# Arsenal  Emiliano Martinez  Arsenal   24       GK             4           1.0
# Arsenal         Mesut Ozil  Arsenal   28       AM             1          50.0
# Arsenal       Granit Xhaka  Arsenal   24       DM             2          35.0
#
#          page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# club
# Arsenal         943        7.0   0.10%          38       2        Spain
# Arsenal        2055        7.5   0.10%          20       2        Spain
# Arsenal         372        4.0   4.20%           8       3    Argentina
# Arsenal        4395        9.5   5.60%         167       2      Germany
# Arsenal        1815        5.5   2.00%          85       2  Switzerland
#
# ...

# %%
#players.head()
#players.drop('club', axis=1)
players.drop('club', axis=1).reset_index().sort_values(['club', 'market_value'],ascending=[True, False]).loc[:,['club', 'market_value']]
#players.sort_index().sort_values(by='market_value', ascending=False).loc[:, ['market_value']]
# Out:
#          club  market_value
# 25    Arsenal          65.0
# 3     Arsenal          50.0
# 20    Arsenal          40.0
# 4     Arsenal          35.0
# 24    Arsenal          35.0
# ..        ...           ...
# 451  West+Ham           5.0
# 444  West+Ham           4.5
# 449  West+Ham           2.5
# 454  West+Ham           2.0
# 439  West+Ham           1.0
#
# [461 rows x 2 columns]

# %%
players.duplicated()
# Out:
# club
# Arsenal     False
# Arsenal     False
# Arsenal     False
# Arsenal     False
# Arsenal     False
#             ...
# West+Ham    False
# West+Ham    False
# West+Ham    False
# West+Ham    False
# West+Ham    False
# Length: 461, dtype: bool

# %%
players = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/soccer.csv")

# %%
players.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
players[players.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
players.duplicated(subset=['club', 'age', 'position', 'market_value'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
players[players.duplicated(subset=['club', 'age', 'position', 'market_value'],keep='last')]
# Out:
#                         name               club  age position  position_cat  \
# 10              Granit Xhaka            Arsenal   24       DM             2
# 12   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 13   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 58                Lewis Dunk  Brighton+and+Hove   25       CB             3
# 253              Fernandinho    Manchester+City   32       DM             2
# 273              Marcos Rojo  Manchester+United   27       CB             3
# 292             Ciaran Clark   Newcastle+United   27       CB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 10           35.0        1815        5.5   2.00%          85       2
# 12           22.0        1519        6.0   1.80%          83       1
# 13           22.0        1519        6.0   1.80%          83       1
# 58            5.0         140        4.5   4.10%           0       1
# ...

# %%
players.drop(index=13)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.drop(labels=[1,2,3,4,5], axis=0)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 6         Olivier Giroud   Arsenal   30       CF             1          22.0
# 7          Nacho Monreal   Arsenal   31       LB             3          13.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.drop(index=[11,12,13])
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.drop(columns=['club', 'age', 'position'])
# Out:
#                     name  position_cat  market_value  page_views  fpl_value  \
# 0         Alexis Sanchez             1          65.0        4329       12.0
# 1             Mesut Ozil             1          50.0        4395        9.5
# 2              Petr Cech             4           7.0        1529        5.5
# 3           Theo Walcott             1          20.0        2393        7.5
# 4      Laurent Koscielny             3          22.0         912        6.0
# ..                   ...           ...           ...         ...        ...
# 460  Edimilson Fernandes             2           5.0         288        4.5
# 461       Arthur Masuaku             3           7.0         199        4.5
# 462            Sam Byram             3           4.5         198        4.5
# 463      Ashley Fletcher             1           1.0         412        4.5
# 464         Diafra Sakho             1          10.0         214        5.5
#
# ...

# %%
a = set([1,2,2,3,4,1])

# %%
a
# Out:
# {1, 2, 3, 4}

# %%
a.difference([1,2])
# Out:
# {3, 4}

# %%
players = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/soccer.csv")

# %%
players[players.isna()]
# Out:
#     name club  age position  position_cat  market_value  page_views  \
# 0    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 1    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 2    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 3    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 4    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# ..   ...  ...  ...      ...           ...           ...         ...
# 460  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 461  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 462  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 463  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 464  NaN  NaN  NaN      NaN           NaN           NaN         NaN
#
#      fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# ...

# %%
import numpy as np

# %%
np.count_nonzero(players.isna())
# Out:
# 4

# %%
players[players.isna().values]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# ...

# %%
df2 = players.drop(labels=[2,10,21]).drop(labels='market_value', axis=1)
df2.head()
# Out:
#                 name     club  age position  position_cat  page_views  \
# 0     Alexis Sanchez  Arsenal   28       LW             1        4329
# 1         Mesut Ozil  Arsenal   28       AM             1        4395
# 3       Theo Walcott  Arsenal   28       RW             1        2393
# 4  Laurent Koscielny  Arsenal   31       CB             3         912
# 5    Hector Bellerin  Arsenal   22       RB             3        1675
#
#    fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# 0       12.0  17.10%         264       3       Chile            0        4
# 1        9.5   5.60%         167       2     Germany            0        4
# 3        7.5   1.50%         122       1     England            0        4
# 4        6.0   0.70%         121       2      France            0        4
# 5        6.0  13.70%         119       2       Spain            0        2
#
#    club_id  big_club  new_signing
# 0        1         1            0
# ...

# %%
nationality = df2['nationality']
nationality[nationality.isna()]
len(nationality.unique())
# Out:
# 61

# %%
df2['combo'] = df2['age'].astype(str) + df2['position']

# %%
df2.head()
# Out:
#                 name     club  age position  position_cat  page_views  \
# 0     Alexis Sanchez  Arsenal   28       LW             1        4329
# 1         Mesut Ozil  Arsenal   28       AM             1        4395
# 3       Theo Walcott  Arsenal   28       RW             1        2393
# 4  Laurent Koscielny  Arsenal   31       CB             3         912
# 5    Hector Bellerin  Arsenal   22       RB             3        1675
#
#    fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# 0       12.0  17.10%         264       3       Chile            0        4
# 1        9.5   5.60%         167       2     Germany            0        4
# 3        7.5   1.50%         122       1     England            0        4
# 4        6.0   0.70%         121       2      France            0        4
# 5        6.0  13.70%         119       2       Spain            0        2
#
#    club_id  big_club  new_signing combo
# 0        1         1            0  28LW
# ...

# %%
df2[df2.duplicated(subset=['club', 'age', 'position'])]
# Out:
#                         name               club  age position  position_cat  \
# 13   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 23   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 31       Alexandre Lacazette            Arsenal   26       CF             1
# 46               Dan Gosling        Bournemouth   27       CM             2
# 59               Shane Duffy  Brighton+and+Hove   25       CB             3
# 74              Pascal Gross  Brighton+and+Hove   26       CM             2
# 84             Ashley Barnes            Burnley   27       CF             1
# 129             Martin Kelly     Crystal+Palace   27       RB             3
# 174        Mathias Jorgensen       Huddersfield   27       CB             3
# 186                 Tom Ince       Huddersfield   25       RW             1
# 188            Andy Williams       Huddersfield   26       CB             3
# ...

# %%
players.select_dtypes(np.number)
# Out:
#      age  position_cat  market_value  page_views  fpl_value  fpl_points  \
# 0     28             1          65.0        4329       12.0         264
# 1     28             1          50.0        4395        9.5         167
# 2     35             4           7.0        1529        5.5         134
# 3     28             1          20.0        2393        7.5         122
# 4     31             3          22.0         912        6.0         121
# ..   ...           ...           ...         ...        ...         ...
# 460   21             2           5.0         288        4.5          38
# 461   23             3           7.0         199        4.5          34
# 462   23             3           4.5         198        4.5          29
# 463   21             1           1.0         412        4.5          16
# 464   27             1          10.0         214        5.5          12
#
#      region  new_foreign  age_cat  club_id  big_club  new_signing
# ...

# %%
ages = players['age']

# %%
ages.int.real()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cw/s321vfbx6j78jd3lsjfcsdyw0000gn/T/ipykernel_93079/1105482322.py in ?()
# ----> 1 ages.int.real()
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'int'

# %%
clubs = players.club

# %%
clubs.str.len()
# Out:
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
#       ..
# 460    8
# 461    8
# 462    8
# 463    8
# 464    8
# Name: club, Length: 465, dtype: int64

# %%
[dtype != object for dtype in players.dtypes]
# Out:
# [False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True]
