# %%
import numpy as np
import pandas as pd
games = pd.read_csv("/Users/bartoszpiechnik/Desktop/pandas-bootcamp/games_sales.csv")

# %%
games.head()
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# 3              Activision      9.03      4.28      0.13         1.32
# 4              Activision      9.67      3.73      0.11         1.13
#
#    Global_Sales
# 0         21.82
# 1         21.40
# 2         16.38
# 3         14.76
# 4         14.64

# %%
games.loc[:, ['Platform', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum()
# Out:
# Platform       X360PS3X360X360X360PS4PS3X360X360PS3PS3X360PS4...
# NA_Sales                                                  1173.3
# EU_Sales                                                  793.64
# JP_Sales                                                  107.06
# Other_Sales                                               282.75
# dtype: object

# %%
games.Platform.unique()
# Out:
# array(['X360', 'PS3', 'PS4', 'XOne'], dtype=object)

# %%
platform_names = {
    'PS3': 'PlayStation',
    'PS4': 'PlayStation',
    'X360': 'XBox',
    'XOne': 'XBox'
}

# %%
sales = games.loc[:, ['Platform', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]

# %%
sales.set_index('Platform').groupby(platform_names).sum()
# Out:
#              NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Platform
# PlayStation    489.06    467.41     94.29       185.29
# XBox           684.24    326.23     12.77        97.46

# %%
games
# Out:
#                                 Name Platform    Year         Genre  \
# 0                 Kinect Adventures!     X360  2010.0          Misc
# 1                 Grand Theft Auto V      PS3  2013.0        Action
# 2                 Grand Theft Auto V     X360  2013.0        Action
# 3     Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 4            Call of Duty: Black Ops     X360  2010.0       Shooter
# ...                              ...      ...     ...           ...
# 3138                  Bound By Flame     X360  2014.0  Role-Playing
# 3139                    Mighty No. 9     XOne  2016.0      Platform
# 3140              Resident Evil 4 HD     XOne  2016.0       Shooter
# 3141   Farming 2017 - The Simulation      PS4  2016.0    Simulation
# 3142               Rugby Challenge 3     XOne  2016.0        Sports
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0     Microsoft Game Studios     14.97      4.94      0.24         1.67
# ...

# %%
publishers = games[['Publisher', 'Genre', 'Platform', 'NA_Sales']]

# %%
pb = publishers.groupby('Publisher').sum(numeric_only=True).nlargest(10, columns='NA_Sales')#.sort_values(by='NA_Sales', ascending=False).

# %%
pb
# Out:
#                                         NA_Sales
# Publisher
# Electronic Arts                           213.38
# Activision                                193.16
# Take-Two Interactive                      120.99
# Microsoft Game Studios                    116.77
# Ubisoft                                    98.65
# Sony Computer Entertainment                76.35
# Warner Bros. Interactive Entertainment     45.24
# THQ                                        36.44
# Bethesda Softworks                         33.88
# Capcom                                     24.74

# %%
top = publishers.groupby('Platform').sum(numeric_only=True).nlargest(1, 'NA_Sales')

# %%
top
# Out:
#           NA_Sales
# Platform
# X360        601.05

# %%
publishers.set_index('Platform').groupby(platform_names).sum().nlargest(1, 'NA_Sales')
# Out:
# /var/folders/cw/s321vfbx6j78jd3lsjfcsdyw0000gn/T/ipykernel_25868/672623900.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   publishers.set_index('Platform').groupby(platform_names).sum().nlargest(1, 'NA_Sales')
#           NA_Sales
# Platform
# XBox        684.24

# %%
sales.head()
# Out:
#   Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0     X360     14.97      4.94      0.24         1.67
# 1      PS3      7.01      9.27      0.97         4.14
# 2     X360      9.63      5.31      0.06         1.38
# 3     X360      9.03      4.28      0.13         1.32
# 4     X360      9.67      3.73      0.11         1.13

# %%
sales.groupby('Platform')['JP_Sales']

# %%
aaa = dict(iter(sales.groupby('Platform')))

# %%
aaa['PS3']
# Out:
#      Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 1         PS3      7.01      9.27      0.97         4.14
# 6         PS3      4.99      5.88      0.65         2.52
# 9         PS3      5.54      5.82      0.49         1.62
# 10        PS3      5.98      4.44      0.48         1.83
# 14        PS3      2.96      4.88      0.81         2.12
# ...       ...       ...       ...       ...          ...
# 3124      PS3      0.00      0.01      0.00         0.00
# 3125      PS3      0.00      0.00      0.01         0.00
# 3129      PS3      0.00      0.00      0.01         0.00
# 3132      PS3      0.00      0.00      0.01         0.00
# 3136      PS3      0.00      0.00      0.01         0.00
#
# [1329 rows x 5 columns]

# %%
studios = games.loc[:, ['Genre', 'Publisher', 'Global_Sales']]

# %%
studios.head()
# Out:
#      Genre               Publisher  Global_Sales
# 0     Misc  Microsoft Game Studios         21.82
# 1   Action    Take-Two Interactive         21.40
# 2   Action    Take-Two Interactive         16.38
# 3  Shooter              Activision         14.76
# 4  Shooter              Activision         14.64

# %%
top_sales = studios.groupby(['Genre', 'Publisher']).sum().sort_values(by='Global_Sales', ascending=False)

# %%
top_sales
# Out:
#                                          Global_Sales
# Genre        Publisher
# Shooter      Activision                        245.46
# Sports       Electronic Arts                   203.50
# Action       Take-Two Interactive              106.04
#              Ubisoft                            96.44
# Shooter      Electronic Arts                    92.58
# ...                                               ...
# Adventure    Cave                                0.01
# Role-Playing TopWare Interactive                 0.01
# Sports       Interworks Unlimited, Inc.          0.01
# Strategy     Ackkstudios                         0.01
# Adventure    Views                               0.01
#
# [422 rows x 1 columns]

# %%
studios.groupby(['Genre', 'Publisher']).agg(['sum', 'count', 'mean'])
# Out:
#                               Global_Sales
#                                        sum count      mean
# Genre    Publisher
# Action   505 Games                    2.25     8  0.281250
#          Abylight                     0.08     1  0.080000
#          Ackkstudios                  0.33     1  0.330000
#          Acquire                      0.11     1  0.110000
#          Activision                  42.84    95  0.450947
# ...                                    ...   ...       ...
# Strategy Square Enix                  0.35     1  0.350000
#          Takara Tomy                  0.09     1  0.090000
#          Take-Two Interactive         2.92     6  0.486667
#          Tecmo Koei                   0.58     6  0.096667
#          Ubisoft                      2.34     4  0.585000
#
# [422 rows x 3 columns]

# %%
studios.groupby(['Genre', 'Publisher']).agg(['sum', 'count', 'mean']).sort_values(by=('Global_Sales', 'sum'), ascending=False)
# Out:
#                                         Global_Sales
#                                                  sum count      mean
# Genre        Publisher
# Shooter      Activision                       245.46    72  3.409167
# Sports       Electronic Arts                  203.50   170  1.197059
# Action       Take-Two Interactive             106.04    23  4.610435
#              Ubisoft                           96.44    67  1.439403
# Shooter      Electronic Arts                   92.58    50  1.851600
# ...                                              ...   ...       ...
# Adventure    Cave                               0.01     1  0.010000
# Role-Playing TopWare Interactive                0.01     1  0.010000
# Sports       Interworks Unlimited, Inc.         0.01     1  0.010000
# Strategy     Ackkstudios                        0.01     1  0.010000
# Adventure    Views                              0.01     1  0.010000
#
# [422 rows x 3 columns]

# %%
games.groupby(['Publisher', 'Genre']).filter(lambda sg: sg['NA_Sales'].sum() > 50)
# Out:
#                                       Name Platform    Year    Genre  \
# 3           Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4                  Call of Duty: Black Ops     X360  2010.0  Shooter
# 5                Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 6               Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 7               Call of Duty: Black Ops II     X360  2012.0  Shooter
# ...                                    ...      ...     ...      ...
# 2908   Cabela's Big Game Hunter: Pro Hunts     X360  2014.0  Shooter
# 3012  Call of Duty: Modern Warfare Trilogy      PS3  2016.0  Shooter
# 3033                                NHL 16     X360  2015.0   Sports
# 3035  Call of Duty: Modern Warfare Trilogy     X360  2016.0  Shooter
# 3078                         Madden NFL 13      PS3  2012.0   Sports
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
def more_than_50(df):
    return df['NA_Sales'].sum() > 50

games.groupby(['Publisher', 'Genre']).filter(more_than_50)
# Out:
#                                       Name Platform    Year    Genre  \
# 3           Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4                  Call of Duty: Black Ops     X360  2010.0  Shooter
# 5                Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 6               Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 7               Call of Duty: Black Ops II     X360  2012.0  Shooter
# ...                                    ...      ...     ...      ...
# 2908   Cabela's Big Game Hunter: Pro Hunts     X360  2014.0  Shooter
# 3012  Call of Duty: Modern Warfare Trilogy      PS3  2016.0  Shooter
# 3033                                NHL 16     X360  2015.0   Sports
# 3035  Call of Duty: Modern Warfare Trilogy     X360  2016.0  Shooter
# 3078                         Madden NFL 13      PS3  2012.0   Sports
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games_rel = games.loc[:, ['Name', 'Genre', 'Platform', 'Global_Sales']]

# %%
games_rel.set_index(['Name', 'Platform']).groupby('Genre').transform(lambda x: (x - x.mean())/x.std())
# Out:
#                                          Global_Sales
# Name                           Platform
# Kinect Adventures!             X360         13.814162
# Grand Theft Auto V             PS3          13.831175
#                                X360         10.468663
# Call of Duty: Modern Warfare 3 X360          5.301112
# Call of Duty: Black Ops        X360          5.253454
# ...                                               ...
# Bound By Flame                 X360         -0.576944
# Mighty No. 9                   XOne         -0.728965
# Resident Evil 4 HD             XOne         -0.556808
# Farming 2017 - The Simulation  PS4          -0.728496
# Rugby Challenge 3              XOne         -0.642965
#
# [3143 rows x 1 columns]

# %%
ps3 = games.loc[games.Platform == 'PS3', ['Name', 'Genre', 'EU_Sales', 'Global_Sales']]

# %%
ps3
# Out:
#                                                    Name       Genre  EU_Sales  \
# 1                                    Grand Theft Auto V      Action      9.27
# 6                            Call of Duty: Black Ops II     Shooter      5.88
# 9                        Call of Duty: Modern Warfare 3     Shooter      5.82
# 10                              Call of Duty: Black Ops     Shooter      4.44
# 14                                       Gran Turismo 5      Racing      4.88
# ...                                                 ...         ...       ...
# 3124                        Hyperdimension Neptunia mk2      Action      0.01
# 3125  Shin Koihime Musou: Otome Taisen * Sangokushi ...   Adventure      0.00
# 3129                                Muv-Luv Alternative  Simulation      0.00
# 3132                           Akatsuki no Goei Trinity   Adventure      0.00
# 3136                                    Battle Fantasia    Fighting      0.00
#
#       Global_Sales
# ...

# %%
ps3.groupby('Genre').apply(lambda sg: 'solid' if sg.EU_Sales.sum() > 50 else 'weak')
# Out:
# Genre
# Action          solid
# Adventure        weak
# Fighting         weak
# Misc             weak
# Platform         weak
# Puzzle           weak
# Racing           weak
# Role-Playing     weak
# Shooter         solid
# Simulation       weak
# Sports           weak
# Strategy         weak
# dtype: object

# %%
def sales_detail(sf):
    level = 'solid' if sf.EU_Sales.sum() > 50 else 'weak'
    variability = 'volatile' if sf.EU_Sales.std()/sf.EU_Sales.mean() > 2 else 'steady'
    return (level, variability)

# %%
ps3.groupby('Genre').apply(sales_detail)
# Out:
# Genre
# Action          (solid, volatile)
# Adventure        (weak, volatile)
# Fighting           (weak, steady)
# Misc               (weak, steady)
# Platform           (weak, steady)
# Puzzle             (weak, steady)
# Racing             (weak, steady)
# Role-Playing     (weak, volatile)
# Shooter           (solid, steady)
# Simulation         (weak, steady)
# Sports           (weak, volatile)
# Strategy           (weak, steady)
# dtype: object

# %%
g_sales = games.loc[:, ['Year', 'Global_Sales']]

# %%
g_by_year = games.groupby('Year').sum()
# Out:
# /var/folders/cw/s321vfbx6j78jd3lsjfcsdyw0000gn/T/ipykernel_25868/2785274439.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g_by_year = games.groupby('Year').sum()

# %%
g_by_year['Global_Sales'].sort_values(ascending=False)
# Out:
# Year
# 2010.0    315.47
# 2011.0    304.49
# 2008.0    255.45
# 2009.0    253.19
# 2013.0    250.36
# 2014.0    238.57
# 2012.0    210.37
# 2015.0    204.23
# 2007.0    169.65
# 2006.0     72.95
# 2016.0     55.04
# 2005.0      8.32
# 2017.0      0.03
# Name: Global_Sales, dtype: float64

# %%
s_games = games.groupby(['Genre', 'Year', 'Platform']).sum()['EU_Sales'].sort_values(ascending=False)
# Out:
# /var/folders/cw/s321vfbx6j78jd3lsjfcsdyw0000gn/T/ipykernel_25868/1794059385.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   s_games = games.groupby(['Genre', 'Year', 'Platform']).sum()['EU_Sales'].sort_values(ascending=False)

# %%
s_games
# Out:
# Genre      Year    Platform
# Action     2013.0  PS3         21.72
#            2014.0  PS4         19.18
#            2012.0  PS3         17.37
#            2011.0  PS3         16.49
# Shooter    2011.0  PS3         15.98
#                                ...
# Adventure  2013.0  X360         0.00
# Strategy   2011.0  PS3          0.00
# Misc       2016.0  PS4          0.00
#                    PS3          0.00
# Puzzle     2006.0  X360         0.00
# Name: EU_Sales, Length: 307, dtype: float64

# %%
games.head()
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# 3              Activision      9.03      4.28      0.13         1.32
# 4              Activision      9.67      3.73      0.11         1.13
#
#    Global_Sales
# 0         21.82
# 1         21.40
# 2         16.38
# 3         14.76
# 4         14.64

# %%
g = games.set_index(['Name', 'Platform', 'Genre']).groupby(['Platform', 'Genre']).sum()
# Out:
# /var/folders/cw/s321vfbx6j78jd3lsjfcsdyw0000gn/T/ipykernel_25868/446138571.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g = games.set_index(['Name', 'Platform', 'Genre']).groupby(['Platform', 'Genre']).sum()

# %%
g
# Out:
#                            Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Platform Genre
# PS3      Action        750197.0    121.16    110.62     29.59        46.51
#          Adventure     144856.0      8.74      8.13      2.68         3.33
#          Fighting      152851.0     23.79     14.69      6.54         6.69
#          Misc          243240.0     22.53     16.92      1.38         6.93
#          Platform       72371.0     13.31     11.38      0.61         5.03
#          Puzzle          4023.0      0.39      0.05      0.10         0.05
#          Racing        180892.0     23.86     33.86      3.13        13.09
#          Role-Playing  235352.0     29.85     19.79     16.82         8.92
#          Shooter       311612.0     81.88     75.14      8.81        30.21
#          Simulation     60309.0      4.30      3.78      1.27         1.41
#          Sports        422172.0     60.58     48.02      7.90        19.17
# ...
